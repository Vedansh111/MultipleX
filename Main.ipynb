# %%
import SimpleGUICS2Pygame.simpleguics2pygame as simplegui

def draw(canvas):
    canvas.draw_text('Click which ever game you want to play!!!', [40,250], 42, 'Black')
    canvas.draw_text('Click reset after playing a game :)', [200,580], 30, 'Black')

def pong():
    # %run Pong.ipynb
    frame.add_label('')
    
def black():   
    # %run BlackJack.ipynb
    frame.add_label('')
    
def shape():
    # %run Shapeshifters.ipynb
    frame.add_label('')
    
def memory():
    # %run Memory.ipynb
    frame.add_label('')
    
def tictactoe():
    # %run TicTacToe.ipynb
    frame.add_label('')
    
def dino():
    # %run Dino_Run.ipynb
    frame.add_label('')
    
def balldot():
    # %run BallDot.ipynb
    frame.add_label('')

def reset():
    frame.add_label('')


# Creating a frame    
frame = simplegui.create_frame("MultipleX", 800,600, 150)
frame.set_canvas_background('lightblue')

# Buttons to access games...
frame.add_button('Pong Game', pong)
frame.add_button('BlackJack', black)
frame.add_button('ShapeShifters', shape)
frame.add_button('Memory Game', memory)
frame.add_button('Tic Tac Toe', tictactoe)
frame.add_button('Dino Jump', dino)
frame.add_button('Ball Dot', balldot)
frame.add_label('')
frame.add_label('Enjoy...')
frame.add_label('')
# frame.add_button("Reset", reset)

# Handlers
frame.set_draw_handler(draw)

# Start
frame.start()
